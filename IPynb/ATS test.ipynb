# %%
cd NewsScrape/
# Out:
# /home/mchan/NewsScrape

# %%
import urllib, urllib2, cookielib, refrom bs4 import BeautifulSoupfrom time import gmtime, localtime, strftimeimport sysfrom datetime import datetime, datetheurl = "http://www.theflyonthewall.com/beta/news.php"txheader =  {'User-Agent' : 'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)'}# Setup RT15 Database accesssys.path.append("/home/mchan/NewsScrape")import dbutil__homeserv = dbutil.db(h='127.0.0.1', schema='mchan')__cursor = __homeserv.cursor# Privoxy vs. Direct access#cj = cookielib.CookieJar()#opener = urllib2.build_opener(urllib2.HTTPCookieProcessor(cj))# Hiding IP address takes 0.4 seconds to get page data# Without proxy its twice as fast 0.2 secondsproxy_support = urllib2.ProxyHandler({"http" : "127.0.0.1:8118"})opener = urllib2.build_opener(proxy_support)print datetime.now()resp = opener.open(theurl)print datetime.now()soup = BeautifulSoup(resp.read())
# Out:
# 2012-09-11 10:05:09.2411542012-09-11 10:05:10.463636

# %%
Event = dict()Event['ticker'] = 'C'sql =  """SELECT s.market_cap_usd_mm FROM mchan.security_price s                 INNER JOIN mchan.mapping m                 ON m.security_id = s.security_id                 WHERE m.ticker = '%s'                 ORDER BY as_of_date DESC                 LIMIT 1;""" % Event['ticker']marketcap = __homeserv.query(sql)print marketcap[0][0]
# Out:
# 80370.3330071

# %%
sql = """SELECT s.eq_region_rank FROM mchan.s_daily s                 INNER JOIN mchan.mapping m                 ON m.security_id = s.security_id                 WHERE m.ticker = '%s'                 ORDER BY as_of_date DESC                 LIMIT 1;""" % Event['ticker'] print datetime.now()eqscore = __homeserv.query(sql)print datetime.now()print eqscore
# Out:
# 2012-08-30 16:30:05.8387492012-08-30 16:30:05.839384[[57L]]

# %%
print soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head><meta content="IE=EmulateIE8" http-equiv="X-UA-Compatible"/><meta content="text/html;charset=utf-8" http-equiv="Content-Type"/><title>the fly on the wall.com</title><link href="theflyFav.png" rel="icon" type="image/png"/><link href="favicon.ico" rel="shortcut icon"/><script src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.1/jquery.min.js" type="text/javascript"></script><link href="/beta/styles//todos.css" rel="stylesheet" type="text/css"/><link href="/beta/css/ui-lightness/jquery-ui-1.8.4.custom.css" rel="stylesheet" type="text/css"/><link href="http://fonts.googleapis.com/css?family=Syncopate" rel="stylesheet" type="text/css"/><!-- comentario condicional para IE6 que carga un css especial para el ie6 --><!--[if IE 6]&gt;&lt;link rel="stylesheet" href="styles/ie6.css" type="text/css"&gt;&lt;![endif]--><!--[if lte IE 8]&gt;&lt;link rel="stylesheet" href="styles/jquery.tabs-ie.cs
# ...

# %%
import pprintpprint soup
# Out:
#   File "<ipython-input-8-4a54cd2e81de>", line 2
#     pprint soup
#               ^
# SyntaxError: invalid syntax

# %%
print soup.prettify()
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html> <head>  <meta content="IE=EmulateIE8" http-equiv="X-UA-Compatible"/>  <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>  <title>   the fly on the wall.com  </title>  <link href="theflyFav.png" rel="icon" type="image/png"/>  <link href="favicon.ico" rel="shortcut icon"/>  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.1/jquery.min.js" type="text/javascript">  </script>  <link href="/beta/styles//todos.css" rel="stylesheet" type="text/css"/>  <link href="/beta/css/ui-lightness/jquery-ui-1.8.4.custom.css" rel="stylesheet" type="text/css"/>  <link href="http://fonts.googleapis.com/css?family=Syncopate" rel="stylesheet" type="text/css"/>  <!-- comentario condicional para IE6 que carga un css especial para el ie6 -->  <!--[if IE 6]&gt;&lt;link rel="stylesheet" href="styles/ie6.css" type="text/css"&gt;&lt;![endif]-->  <!--[if lte IE 8]&gt;&lt;link rel="stylesheet
# ...

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head><meta content="IE=EmulateIE8" http-equiv="X-UA-Compatible"/><meta content="text/html;charset=utf-8" http-equiv="Content-Type"/><title>the fly on the wall.com</title><link href="theflyFav.png" rel="icon" type="image/png"/><link href="favicon.ico" rel="shortcut icon"/><script src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.1/jquery.min.js" type="text/javascript"></script><link href="/beta/styles//todos.css" rel="stylesheet" type="text/css"/><link href="/beta/css/ui-lightness/jquery-ui-1.8.4.custom.css" rel="stylesheet" type="text/css"/><link href="http://fonts.googleapis.com/css?family=Syncopate" rel="stylesheet" type="text/css"/><!-- comentario condicional para IE6 que carga un css especial para el ie6 --><!--[if IE 6]&gt;&lt;link rel="stylesheet" href="styles/ie6.css" type="text/css"&gt;&lt;![endif]--><!--[if lte IE 8]&gt;&lt;link rel="stylesheet" href="styles/jquery.tabs-ie.cs
# ...

# %%
sys.path.append('/home/mchan/git/Artemis/Trading')import strategy

# %%
reload(strategy)strat1 = strategy.LongEarningsGuidance()strat2 = strategy.ShortEarningsGuidance()

# %%
event = dict()stories = __homeserv.query("select * from mchan.flyonthewall where date(release_date) > '2012-08-31' order by release_date;")

# %%
for row in stories:    #print row[3], row[4], row[5]    event['ticker'] = row[3]    event['classification'] = row[4]    event['headline'] = row[5]    if strat1.isEvent(event):        print "LONG", row    elif strat2.isEvent(event):        print "SHORT", row
# Out:
# SHORT [1698379L, datetime.datetime(2012, 9, 4, 16, 2, 19), datetime.datetime(2012, 9, 4, 13, 6, 2), 'FNSR', 'Earnings', ' Finisar sees Q2 EPS 12c-16c, consensus 19c', 'Sees Q2 revenue $225M-$240M, consensus $236.22M. Sees operating margin to in the range of approximately 0.0% to 1.5% and non-GAAP operating margin to be in the range of approximately 5.7% to 7.2%. ', '']SHORT [1698387L, datetime.datetime(2012, 9, 4, 16, 5, 33), datetime.datetime(2012, 9, 4, 13, 10, 3), 'TEA', 'Earnings', ' Teavana sees FY12 EPS 53c-55c, consensus 57c', 'Sees net sales including Teaopia are expected to be in the range of $222M-$231M, consensus $220.11M. Guidance based on opening 60 new stores and an increase in comparable sales, including e-commerce and excluding Teaopia, in the low single digit range. Teaopia is expected to reduce net income per diluted share by 3c, driven by a neutral impact from operations and 3c per diluted share in one-time transaction and integration expenses. ', '']LONG
# ...

# %%
58/2
# Out:
# 29

# %%
import fowscannerpastEvents = dict()

# %%
# Out:
# False

# %%
events = fowscanner.scan()for row in events:    if row[0] not in pastEvents:        pastEvents[row[0]] = row        print row
# Out:
# ('1699166', u'2012-09-05 12:02:12', 'Market Commentary', [u'MBI', u'NOK', u'EMCF', u'FRAN', u'OYOG', u'BONT', u'CCRN', u'NOK', u'DOM', u'AUQ', u'GWRE', u'CCM', u'AVY', u'AVY', u'MMM', u'AVY', u'ABB', u'MO', u'DIS', u'CROX', u'YELP', u'POL', u'SLCA', u'YELP', u'YELP', u'GOOG', u'VRTU', u'UPS', u'UPS', u'TNTEY', u'ANDE', u'JIVE', u'ALTR', u'XTXI', u'TPCG', u'XTEX', u'$NYE', u'HIMX', u'XIN', u'$NSD', u'WPRT', u'NOK', u'SPG', u'RSG', u'GPOR', u'LRCX', u'CVS', u'JASO', u'FTNT', u'COP', u'CVS', u'PDCE'], u' Starbucks climbs after analyst says company can beat expectations', u'Get a trial to see story now.Story free tomorrow.', '')('1699165', u'2012-09-05 12:01:54', 'Hot Stocks', [u'MBI'], u' MBIA settles shareholder suit in NY federal court, Bloomberg reports', u' MBIA settles shareholder suit in NY federal court, Bloomberg reports', '')('1699164', u'2012-09-05 12:01:34', 'Recommendations', [u'NOK'], u' Nokia launch of new smartphones disappointing,  says Wells Fargo', u'Get a trial to see
# ...

# %%
animal = dict()for i in range(0,100):    animal['dog' + str(i)] = str(i)

# %%
pastEvents
# Out:
# {'1698203': ('1698203',  u'2012-09-05 11:25:00',  'Conference/Events',  [u'JIVE'],  u' Jive Software management to meet with BMO Capital',  u'Group luncheon  to be held in Toronto on September 5 hosted by BMO Capital.  theflyonthewall.com',  ''), '1698716': ('1698716',  u'2012-09-05 10:55:00',  'Conference/Events',  [u'CNO'],  u' CNO Financial to host a conference call',  u'Get a trial to see story now.Story free tomorrow.',  ''), '1699101': ('1699101',  u'2012-09-05 10:48:53',  'Hot Stocks',  [u'CVS'],  u' CVS Caremark says seeing pressure in reimbursement',  u' CVS Caremark says seeing pressure in reimbursement',  ''), '1699102': ('1699102',  u'2012-09-05 10:52:18',  'Periodicals',  [u'GOOG'],  u" Google's YouTube to offer movie rentals on TVs, GIGAom says",  u'Get a trial to see story now.Story free tomorrow.',  ''), '1699103': ('1699103',  u'2012-09-05 10:53:51',  'Hot Stocks',  [u'ETR', u'ETR', u'ITC'],  u' Entergy, ITC initiate transaction approval process with Lousiana PSC fil
# ...

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head><meta content="IE=EmulateIE8" http-equiv="X-UA-Compatible"/><meta content="text/html;charset=utf-8" http-equiv="Content-Type"/><title>the fly on the wall.com</title><link href="theflyFav.png" rel="icon" type="image/png"/><link href="favicon.ico" rel="shortcut icon"/><script src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.1/jquery.min.js" type="text/javascript"></script><link href="/beta/styles//todos.css" rel="stylesheet" type="text/css"/><link href="/beta/css/ui-lightness/jquery-ui-1.8.4.custom.css" rel="stylesheet" type="text/css"/><link href="http://fonts.googleapis.com/css?family=Syncopate" rel="stylesheet" type="text/css"/><!-- comentario condicional para IE6 que carga un css especial para el ie6 --><!--[if IE 6]&gt;&lt;link rel="stylesheet" href="styles/ie6.css" type="text/css"&gt;&lt;![endif]--><!--[if lte IE 8]&gt;&lt;link rel="stylesheet" href="styles/jquery.tabs-ie.cs
# ...
