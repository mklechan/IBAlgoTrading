# %%
import operatorimport kNN

# %%
group, labels = kNN.createDataSet()

# %%
group
# Out:
# array([[ 1. ,  1.1],       [ 1. ,  1. ],       [ 0. ,  0. ],       [ 0. ,  0.1]])

# %%
labels
# Out:
# ['A', 'A', 'B', 'B']

# %%
# ?kNN

# %%
kNN.classify0([1.1,0.1], group, labels, 3)
# Out:
# 'A'

# %%
reload(kNN)datingDataMat,datingLabels = kNN.file2matrix('datingTestSet2.txt')

# %%
datingDataMat
# Out:
# array([[  4.09200000e+04,   8.32697600e+00,   9.53952000e-01],       [  1.44880000e+04,   7.15346900e+00,   1.67390400e+00],       [  2.60520000e+04,   1.44187100e+00,   8.05124000e-01],       ...,        [  2.65750000e+04,   1.06501020e+01,   8.66627000e-01],       [  4.81110000e+04,   9.13452800e+00,   7.28045000e-01],       [  4.37570000e+04,   7.88260100e+00,   1.33244600e+00]])

# %%
datingLabels[0:20]
# Out:
# [3, 2, 1, 1, 1, 1, 3, 3, 1, 3, 1, 1, 2, 1, 1, 1, 1, 1, 2, 3]

# %%
import matplotlibimport matplotlib.pyplot as pltfig = plt.figure()ax = fig.add_subplot(111)ax.scatter(datingDataMat[:,1], datingDataMat[:,2],15.0*array(datingLabels), 15.0*array(datingLabels))figsize(15,10)plt.show()
